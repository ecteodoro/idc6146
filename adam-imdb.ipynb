# %%
# %pip install tensorflow==2.10.0

# %%
# Deep Learning for Data Science
# University of West Florida
#
# Project: Adam Optimizer
# 
# Evaluate the performance of the Adam optimizer
# on the IMDB dataset using a simple neural network.
#
# =============================================================================

# Import necessary libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.text import Tokenizer

# Load the IMDb dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# Decode the reviews back to text (for understanding)
word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in text])

decoded_reviews = [decode_review(review) for review in x_train[:5]]
for i, review in enumerate(decoded_reviews):
    print(f"Review {i + 1}: {review}")
# Out:
# Review 1: ? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all
# Review 2: ? big hair big boobs bad music and a giant safety pin these are the words to best describe this terrible movie i love cheesy horror movies and i've seen hundreds but this had got to be on of the worst ever made the plot is paper thin and ridiculous the acting is an abomination the script is completely laughable the best is the end showdown with the cop and how he worked out who the killer is it's just so damn terribly written the clothes are sickening and funny in equal ? the hair is big lots of boobs ? men wear those cut ? shirts that show off their ? sickening that men actually wore them and the music is just ? trash that plays over and over again in almost every scene there is trashy music boobs and ? taking away bodies and the gym still doesn't close for ? all joking aside this is a truly bad film whose only charm is to look back on the disaster that was the 80's and have a good old laugh at how bad everything was back then
# Review 3: ? this has to be one of the worst films of the 1990s when my friends i were watching this film being the target audience it was aimed at we just sat watched the first half an hour with our jaws touching the floor at how bad it really was the rest of the time everyone else in the theatre just started talking to each other leaving or generally crying into their popcorn that they actually paid money they had ? working to watch this feeble excuse for a film it must have looked like a great idea on paper but on film it looks like no one in the film has a clue what is going on crap acting crap costumes i can't get across how ? this is to watch save yourself an hour a bit of your life
# Review 4: ? the ? ? at storytelling the traditional sort many years after the event i can still see in my ? eye an elderly lady my friend's mother retelling the battle of ? she makes the characters come alive her passion is that of an eye witness one to the events on the ? heath a mile or so from where she lives br br of course it happened many years before she was born but you wouldn't guess from the way she tells it the same story is told in bars the length and ? of scotland as i discussed it with a friend one night in ? a local cut in to give his version the discussion continued to closing time br br stories passed down like this become part of our being who doesn't remember the stories our parents told us when we were children they become our invisible world and as we grow older they maybe still serve as inspiration or as an emotional ? fact and fiction blend with ? role models warning stories ? magic and mystery br br my name is ? like my grandfather and his grandfather before him our protagonist introduces himself to us and also introduces the story that stretches back through generations it produces stories within stories stories that evoke the ? wonder of scotland its rugged mountains ? in ? the stuff of legend yet ? is ? in reality this is what gives it its special charm it has a rough beauty and authenticity ? with some of the finest ? singing you will ever hear br br ? ? visits his grandfather in hospital shortly before his death he burns with frustration part of him ? to be in the twenty first century to hang out in ? but he is raised on the western ? among a ? speaking community br br yet there is a deeper conflict within him he ? to know the truth the truth behind his ? ancient stories where does fiction end and he wants to know the truth behind the death of his parents br br he is pulled to make a last ? journey to the ? of one of ? most ? mountains can the truth be told or is it all in stories br br in this story about stories we ? bloody battles ? lovers the ? of old and the sometimes more ? ? of accepted truth in doing so we each connect with ? as he lives the story of his own life br br ? the ? ? is probably the most honest ? and genuinely beautiful film of scotland ever made like ? i got slightly annoyed with the ? of hanging stories on more stories but also like ? i ? this once i saw the ? picture ' forget the box office ? of braveheart and its like you might even ? the ? famous ? of the wicker man to see a film that is true to scotland this one is probably unique if you maybe ? on it deeply enough you might even re ? the power of storytelling and the age old question of whether there are some truths that cannot be told but only experienced
# Review 5: ? worst mistake of my life br br i picked this movie up at target for 5 because i figured hey it's sandler i can get some cheap laughs i was wrong completely wrong mid way through the film all three of my friends were asleep and i was still suffering worst plot worst script worst movie i have ever seen i wanted to hit my head up against a wall for an hour then i'd stop and you know why because it felt damn good upon bashing my head in i stuck that damn movie in the ? and watched it burn and that felt better than anything else i've ever done it took american psycho army of darkness and kill bill just to get over that crap i hate you sandler for actually going through with this and ruining a whole day of my life

# %%
# Initialize the tokenizer with the top 10,000 words
tokenizer = Tokenizer(num_words=10000)
x_train_texts = [decode_review(review) for review in x_train]
x_test_texts = [decode_review(review) for review in x_test]

# Fit the tokenizer on the training texts
tokenizer.fit_on_texts(x_train_texts)

# Convert the texts to BoW vectors
x_train_bow = tokenizer.texts_to_matrix(x_train_texts, mode='binary')
x_test_bow = tokenizer.texts_to_matrix(x_test_texts, mode='binary')

# Check the shape of the BoW feature vectors
print(f"x_train_bow shape: {x_train_bow.shape}")
print(f"x_test_bow shape: {x_test_bow.shape}")
# Out:
# x_train_bow shape: (25000, 10000)
# x_test_bow shape: (25000, 10000)

# %%
# Calculate sparsity
train_sparsity = 1.0 - np.count_nonzero(x_train_bow) / x_train_bow.size
test_sparsity = 1.0 - np.count_nonzero(x_test_bow) / x_test_bow.size

print(f"Training data sparsity: {train_sparsity:.4f}")
print(f"Test data sparsity: {test_sparsity:.4f}")
# Out:
# Training data sparsity: 0.9870
# Test data sparsity: 0.9873

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adagrad

def create_bow_model():
    model = Sequential([
        Dense(512, activation='relu', input_shape=(10000,)),
        Dropout(0.5),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    return model

# %%
# %%time
# Compile and train the model with several optimizers

def train_model(optimizer, x_train, y_train, x_val, y_val):
  model = create_bow_model()
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
  history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=180, batch_size=512, validation_split=0.2, verbose=2)
  return model, history

adam_lr_model, adam_lr_history = train_model(Adam(), x_train_bow, y_train, x_test_bow, y_test)
rmsprop_lr_model, rmsprop_lr_history = train_model(RMSprop(), x_train_bow, y_train, x_test_bow, y_test)
adagrad_lr_model, adagrad_lr_history = train_model(Adagrad(learning_rate=0.01), x_train_bow, y_train, x_test_bow, y_test)
sgd_lr_model, sgd_lr_history = train_model(SGD(learning_rate=0.01, nesterov=True), x_train_bow, y_train, x_test_bow, y_test)
# Out:
# 2024-07-21 13:31:42.838283: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1
loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.9663 - val_accuracy: 0.8706 - 4s/epoch - 82ms/step
# Epoch 42/180
# 49/49 - 5s - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.9794 - val_accuracy: 0.8716 - 5s/epoch - 103ms/step
# Epoch 43/180
# 49/49 - 5s - loss: 0.0030 - accuracy: 0.9988 - val_loss: 0.9187 - val_accuracy: 0.8721 - 5s/epoch - 94ms/step
# Epoch 44/180
# 49/49 - 4s - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.9197 - val_accuracy: 0.8710 - 4s/epoch - 90ms/step
# Epoch 45/180
# 49/49 - 5s - loss: 0.0044 - accuracy: 0.9994 - val_loss: 0.9670 - val_accuracy: 0.8707 - 5s/epoch - 97ms/step
# Epoch 46/180
# 49/49 - 5s - loss: 0.0020 - accuracy: 0.9993 - val_loss: 1.0237 - val_accuracy: 0.8694 - 5s/epoch - 94ms/step
# Epoch 47/180
# 49/49 - 4s - loss: 0.0030 - accuracy: 0.9990 - val_loss: 1.0115 - val_accuracy: 0.8698 - 4s/epoch - 92ms/step
# Epoch 48/180
# 49/49 - 5s - loss: 0.0024 - accuracy: 0.9990 - val_loss: 1.0114 - val_accuracy: 0.8698 - 5s/epoch - 101ms/step
# Epoch 49/180
# 49/49 - 6s - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.9543 - val_accuracy: 0.8692 - 6s/epoch - 114ms/step
# Epoch 50/180
# 49/49 - 4s - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.9464 - val_accuracy: 0.8711 - 4s/epoch - 86ms/step
# Epoch 51/180
# 49/49 - 5s - loss: 0.0028 - accuracy: 0.9991 - val_loss: 1.0061 - val_accuracy: 0.8718 - 5s/epoch - 104ms/step
# Epoch 52/180
# 49/49 - 5s - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.9587 - val_accuracy: 0.8696 - 5s/epoch - 105ms/step
# Epoch 53/180
# 49/49 - 4s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 1.0054 - val_accuracy: 0.8732 - 4s/epoch - 88ms/step
# Epoch 54/180
# 49/49 - 4s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 1.0075 - val_accuracy: 0.8706 - 4s/epoch - 86ms/step
# Epoch 55/180
# 49/49 - 4s - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.9860 - val_accuracy: 0.8709 - 4s/epoch - 92ms/step
# Epoch 56/180
# 49/49 - 4s - loss: 0.0030 - accuracy: 0.9991 - val_loss: 1.0837 - val_accuracy: 0.8721 - 4s/epoch - 80ms/step
# Epoch 57/180
# 49/49 - 4s - loss: 0.0041 - accuracy: 0.9986 - val_loss: 1.0053 - val_accuracy: 0.8693 - 4s/epoch - 88ms/step
# Epoch 58/180
# 49/49 - 5s - loss: 0.0038 - accuracy: 0.9986 - val_loss: 1.0318 - val_accuracy: 0.8717 - 5s/epoch - 101ms/step
# Epoch 59/180
# 49/49 - 5s - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.9535 - val_accuracy: 0.8734 - 5s/epoch - 95ms/step
# Epoch 60/180
# 49/49 - 4s - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.9987 - val_accuracy: 0.8730 - 4s/epoch - 90ms/step
# Epoch 61/180
# 49/49 - 5s - loss: 0.0041 - accuracy: 0.9985 - val_loss: 1.0050 - val_accuracy: 0.8719 - 5s/epoch - 103ms/step
# Epoch 62/180
# 49/49 - 5s - loss: 0.0030 - accuracy: 0.9992 - val_loss: 1.0106 - val_accuracy: 0.8759 - 5s/epoch - 105ms/step
# Epoch 63/180
# 49/49 - 4s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.9911 - val_accuracy: 0.8723 - 4s/epoch - 81ms/step
# Epoch 64/180
# 49/49 - 5s - loss: 0.0042 - accuracy: 0.9986 - val_loss: 1.0030 - val_accuracy: 0.8689 - 5s/epoch - 96ms/step
# Epoch 65/180
# 49/49 - 4s - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.9335 - val_accuracy: 0.8724 - 4s/epoch - 77ms/step
# Epoch 66/180
# 49/49 - 4s - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.9087 - val_accuracy: 0.8731 - 4s/epoch - 87ms/step
# Epoch 67/180
# 49/49 - 4s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.9962 - val_accuracy: 0.8713 - 4s/epoch - 87ms/step
# Epoch 68/180
# 49/49 - 4s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 1.0202 - val_accuracy: 0.8718 - 4s/epoch - 83ms/step
# Epoch 69/180
# 49/49 - 4s - loss: 0.0031 - accuracy: 0.9991 - val_loss: 1.0220 - val_accuracy: 0.8697 - 4s/epoch - 84ms/step
# Epoch 70/180
# 49/49 - 4s - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.9850 - val_accuracy: 0.8702 - 4s/epoch - 92ms/step
# Epoch 71/180
# 49/49 - 6s - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.9480 - val_accuracy: 0.8733 - 6s/epoch - 124ms/step
# Epoch 72/180
# 49/49 - 7s - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.8991 - val_accuracy: 0.8730 - 7s/epoch - 137ms/step
# Epoch 73/180
# 49/49 - 5s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.9157 - val_accuracy: 0.8750 - 5s/epoch - 103ms/step
# Epoch 74/180
# 49/49 - 5s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.9271 - val_accuracy: 0.8739 - 5s/epoch - 101ms/step
# Epoch 75/180
# 49/49 - 4s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.9774 - val_accuracy: 0.8722 - 4s/epoch - 90ms/step
# Epoch 76/180
# 49/49 - 4s - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.9809 - val_accuracy: 0.8718 - 4s/epoch - 88ms/step
# Epoch 77/180
# 49/49 - 4s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 1.0239 - val_accuracy: 0.8717 - 4s/epoch - 90ms/step
# Epoch 78/180
# 49/49 - 4s - loss: 0.0018 - accuracy: 0.9994 - val_loss: 1.0221 - val_accuracy: 0.8702 - 4s/epoch - 88ms/step
# Epoch 79/180
# 49/49 - 5s - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.9886 - val_accuracy: 0.8730 - 5s/epoch - 95ms/step
# Epoch 80/180
# 49/49 - 4s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.9859 - val_accuracy: 0.8709 - 4s/epoch - 88ms/step
# Epoch 81/180
# 49/49 - 4s - loss: 0.0015 - accuracy: 0.9994 - val_loss: 1.0189 - val_accuracy: 0.8751 - 4s/epoch - 85ms/step
# Epoch 82/180
# 49/49 - 5s - loss: 0.0012 - accuracy: 0.9994 - val_loss: 1.0585 - val_accuracy: 0.8741 - 5s/epoch - 96ms/step
# Epoch 83/180
loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.9015 - val_accuracy: 0.8755 - 4s/epoch - 84ms/step
# Epoch 103/180
# 49/49 - 4s - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.9482 - val_accuracy: 0.8741 - 4s/epoch - 87ms/step
# Epoch 104/180
# 49/49 - 4s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.9779 - val_accuracy: 0.8746 - 4s/epoch - 87ms/step
# Epoch 105/180
# 49/49 - 4s - loss: 6.3073e-04 - accuracy: 0.9998 - val_loss: 1.0220 - val_accuracy: 0.8734 - 4s/epoch - 84ms/step
# Epoch 106/180
# 49/49 - 4s - loss: 9.3474e-04 - accuracy: 0.9996 - val_loss: 1.0887 - val_accuracy: 0.8745 - 4s/epoch - 86ms/step
# Epoch 107/180
# 49/49 - 5s - loss: 6.7350e-04 - accuracy: 0.9998 - val_loss: 1.0183 - val_accuracy: 0.8749 - 5s/epoch - 96ms/step
# Epoch 108/180
# 49/49 - 5s - loss: 2.8085e-04 - accuracy: 0.9999 - val_loss: 1.0481 - val_accuracy: 0.8734 - 5s/epoch - 93ms/step
# Epoch 109/180
# 49/49 - 5s - loss: 6.0788e-04 - accuracy: 0.9998 - val_loss: 1.0677 - val_accuracy: 0.8743 - 5s/epoch - 98ms/step
# Epoch 110/180
# 49/49 - 5s - loss: 9.7823e-04 - accuracy: 0.9997 - val_loss: 1.0713 - val_accuracy: 0.8737 - 5s/epoch - 94ms/step
# Epoch 111/180
# 49/49 - 4s - loss: 5.3555e-04 - accuracy: 0.9998 - val_loss: 1.1324 - val_accuracy: 0.8732 - 4s/epoch - 88ms/step
# Epoch 112/180
# 49/49 - 5s - loss: 6.3759e-04 - accuracy: 0.9997 - val_loss: 1.1572 - val_accuracy: 0.8735 - 5s/epoch - 99ms/step
# Epoch 113/180
# 49/49 - 5s - loss: 7.3135e-04 - accuracy: 0.9998 - val_loss: 1.0986 - val_accuracy: 0.8737 - 5s/epoch - 99ms/step
# Epoch 114/180
# 49/49 - 5s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 1.0151 - val_accuracy: 0.8706 - 5s/epoch - 111ms/step
# Epoch 115/180
# 49/49 - 5s - loss: 0.0019 - accuracy: 0.9995 - val_loss: 1.0745 - val_accuracy: 0.8735 - 5s/epoch - 106ms/step
# Epoch 116/180
# 49/49 - 5s - loss: 0.0021 - accuracy: 0.9995 - val_loss: 1.0300 - val_accuracy: 0.8720 - 5s/epoch - 99ms/step
# Epoch 117/180
# 49/49 - 5s - loss: 0.0024 - accuracy: 0.9993 - val_loss: 1.0383 - val_accuracy: 0.8705 - 5s/epoch - 98ms/step
# Epoch 118/180
# 49/49 - 5s - loss: 0.0018 - accuracy: 0.9993 - val_loss: 1.1440 - val_accuracy: 0.8695 - 5s/epoch - 96ms/step
# Epoch 119/180
# 49/49 - 5s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 1.1728 - val_accuracy: 0.8689 - 5s/epoch - 102ms/step
# Epoch 120/180
# 49/49 - 5s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 1.1421 - val_accuracy: 0.8681 - 5s/epoch - 96ms/step
# Epoch 121/180
# 49/49 - 5s - loss: 0.0015 - accuracy: 0.9994 - val_loss: 1.1532 - val_accuracy: 0.8719 - 5s/epoch - 93ms/step
# Epoch 122/180
# 49/49 - 5s - loss: 0.0020 - accuracy: 0.9994 - val_loss: 1.0978 - val_accuracy: 0.8720 - 5s/epoch - 100ms/step
# Epoch 123/180
# 49/49 - 5s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 1.1191 - val_accuracy: 0.8729 - 5s/epoch - 93ms/step
# Epoch 124/180
# 49/49 - 4s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 1.1008 - val_accuracy: 0.8728 - 4s/epoch - 88ms/step
# Epoch 125/180
# 49/49 - 5s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 1.1401 - val_accuracy: 0.8747 - 5s/epoch - 106ms/step
# Epoch 126/180
# 49/49 - 5s - loss: 0.0035 - accuracy: 0.9994 - val_loss: 1.3125 - val_accuracy: 0.8618 - 5s/epoch - 94ms/step
# Epoch 127/180
# 49/49 - 5s - loss: 0.0050 - accuracy: 0.9984 - val_loss: 1.0689 - val_accuracy: 0.8724 - 5s/epoch - 100ms/step
# Epoch 128/180
# 49/49 - 5s - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.9996 - val_accuracy: 0.8736 - 5s/epoch - 105ms/step
# Epoch 129/180
# 49/49 - 5s - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.9533 - val_accuracy: 0.8727 - 5s/epoch - 98ms/step
# Epoch 130/180
# 49/49 - 5s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 1.0220 - val_accuracy: 0.8760 - 5s/epoch - 106ms/step
# Epoch 131/180
# 49/49 - 4s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 1.0044 - val_accuracy: 0.8734 - 4s/epoch - 88ms/step
# Epoch 132/180
# 49/49 - 4s - loss: 0.0018 - accuracy: 0.9994 - val_loss: 1.0490 - val_accuracy: 0.8744 - 4s/epoch - 88ms/step
# Epoch 133/180
# 49/49 - 5s - loss: 4.6990e-04 - accuracy: 0.9999 - val_loss: 1.0724 - val_accuracy: 0.8745 - 5s/epoch - 95ms/step
# Epoch 134/180
# 49/49 - 4s - loss: 9.9964e-04 - accuracy: 0.9998 - val_loss: 1.0447 - val_accuracy: 0.8738 - 4s/epoch - 91ms/step
# Epoch 135/180
# 49/49 - 4s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 1.1222 - val_accuracy: 0.8737 - 4s/epoch - 91ms/step
# Epoch 136/180
# 49/49 - 5s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 1.1237 - val_accuracy: 0.8752 - 5s/epoch - 94ms/step
# Epoch 137/180
# 49/49 - 5s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 1.0777 - val_accuracy: 0.8740 - 5s/epoch - 100ms/step
# Epoch 138/180
# 49/49 - 5s - loss: 0.0022 - accuracy: 0.9994 - val_loss: 1.1266 - val_accuracy: 0.8658 - 5s/epoch - 98ms/step
# Epoch 139/180
# 49/49 - 4s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 1.0221 - val_accuracy: 0.8756 - 4s/epoch - 87ms/step
# Epoch 140/180
# 49/49 - 4s - loss: 9.7021e-04 - accuracy: 0.9998 - val_loss: 1.0341 - val_accuracy: 0.8735 - 4s/epoch - 83ms/step
# Epoch 141/180
# 49/49 - 4s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 1.0515 - val_accuracy: 0.8748 - 4s/epoch - 89ms/step
# Epoch 142/180
# 49/49 - 4s - loss: 0.0027 - accuracy: 0.9992 - val_loss: 1.1381 - val_accuracy: 0.8760 - 4s/epoch - 91ms/step
# Epoch 143/180
# 49/49 - 4s - loss: 0.0017 - accuracy: 0.9994 - val_loss: 1.1203 - val_accuracy: 0.8752 - 4s/epoch - 88ms/step
# Epoch 144/180
# 49/49 - 4s - loss: 0.0018 - accuracy: 0.9996 - val_loss: 1.0857 - val_accuracy: 0.8738 - 4s/epoch - 92ms/step
# Epoch 145/180
# 49/49 - 4s - loss: 9.7297e-04 - accuracy: 0.9997 - val_loss: 1.1175 - val_accuracy: 0.8724 - 4s/epoch - 85ms/step
# Epoch 146/180
# 49/49 - 5s - loss: 0.0015 - accuracy: 0.9995 - val_loss: 1.0517 - val_accuracy: 0.8739 - 5s/epoch - 95ms/step
# Epoch 147/180
# 49/49 - 5s - loss: 3.5570e-04 - accuracy: 1.0000 - val_loss: 1.1033 - val_accuracy: 0.8712 - 5s/epoch - 93ms/step
# Epoch 148/180
# 49/49 - 4s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 1.0365 - val_accuracy: 0.8729 - 4s/epoch - 82ms/step
# Epoch 149/180
# 49/49 - 5s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 1.0494 - val_accuracy: 0.8715 - 5s/epoch - 93ms/step
# Epoch 150/180
# 49/49 - 4s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 1.0857 - val_accuracy: 0.8701 - 4s/epoch - 89ms/step
# Epoch 151/180
# 49/49 - 4s - loss: 8.7811e-04 - accuracy: 0.9996 - val_loss: 1.1342 - val_accuracy: 0.8738 - 4s/epoch - 86ms/step
# Epoch 152/180
# 49/49 - 5s - loss: 0.0012 - accuracy: 0.9998 - val_loss: 1.0760 - val_accuracy: 0.8744 - 5s/epoch - 100ms/step
# Epoch 153/180
# 49/49 - 4s - loss: 6.7334e-04 - accuracy: 0.9998 - val_loss: 1.0731 - val_accuracy: 0.8731 - 4s/epoch - 90ms/step
# Epoch 154/180
# 49/49 - 4s - loss: 6.8741e-04 - accuracy: 0.9999 - val_loss: 1.0746 - val_accuracy: 0.8747 - 4s/epoch - 83ms/step
# Epoch 155/180
# 49/49 - 5s - loss: 2.0655e-04 - accuracy: 1.0000 - val_loss: 1.0837 - val_accuracy: 0.8749 - 5s/epoch - 98ms/step
# Epoch 156/180
# 49/49 - 5s - loss: 4.0686e-04 - accuracy: 0.9999 - val_loss: 1.0682 - val_accuracy: 0.8743 - 5s/epoch - 93ms/step
# Epoch 157/180
# 49/49 - 4s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 1.0929 - val_accuracy: 0.8728 - 4s/epoch - 88ms/step
# Epoch 158/180
# 49/49 - 5s - loss: 7.5816e-04 - accuracy: 0.9998 - val_loss: 1.0931 - val_accuracy: 0.8730 - 5s/epoch - 95ms/step
# Epoch 159/180
# 49/49 - 5s - loss: 4.7741e-04 - accuracy: 0.9998 - val_loss: 1.0356 - val_accuracy: 0.8738 - 5s/epoch - 100ms/step
# Epoch 160/180
# 49/49 - 5s - loss: 2.8541e-04 - accuracy: 0.9999 - val_loss: 1.0579 - val_accuracy: 0.8748 - 5s/epoch - 94ms/step
# Epoch 161/180
# 49/49 - 5s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.9894 - val_accuracy: 0.8744 - 5s/epoch - 96ms/step
# Epoch 162/180
# 49/49 - 5s - loss: 3.7584e-04 - accuracy: 0.9999 - val_loss: 1.0308 - val_accuracy: 0.8752 - 5s/epoch - 105ms/step
# Epoch 163/180
# 49/49 - 4s - loss: 3.2869e-04 - accuracy: 0.9999 - val_loss: 1.0540 - val_accuracy: 0.8750 - 4s/epoch - 91ms/step
# Epoch 164/180
# 49/49 - 5s - loss: 2.1111e-04 - accuracy: 1.0000 - val_loss: 1.0556 - val_accuracy: 0.8757 - 5s/epoch - 96ms/step
# Epoch 165/180
# 49/49 - 5s - loss: 2.9835e-04 - accuracy: 0.9999 - val_loss: 1.0758 - val_accuracy: 0.8765 - 5s/epoch - 97ms/step
# Epoch 166/180
# 49/49 - 5s - loss: 3.6754e-04 - accuracy: 0.9999 - val_loss: 1.0870 - val_accuracy: 0.8757 - 5s/epoch - 98ms/step
# Epoch 167/180
# 49/49 - 5s - loss: 8.6693e-04 - accuracy: 0.9998 - val_loss: 1.1136 - val_accuracy: 0.8729 - 5s/epoch - 102ms/step
# Epoch 168/180
# 49/49 - 4s - loss: 9.4957e-04 - accuracy: 0.9997 - val_loss: 1.1026 - val_accuracy: 0.8726 - 4s/epoch - 90ms/step
# Epoch 169/180
# 49/49 - 5s - loss: 4.8720e-04 - accuracy: 0.9998 - val_loss: 1.1192 - val_accuracy: 0.8747 - 5s/epoch - 111ms/step
# Epoch 170/180
# 49/49 - 5s - loss: 6.8649e-04 - accuracy: 0.9997 - val_loss: 1.1251 - val_accuracy: 0.8756 - 5s/epoch - 99ms/step
# Epoch 171/180
# 49/49 - 5s - loss: 0.0018 - accuracy: 0.9996 - val_loss: 1.0940 - val_accuracy: 0.8745 - 5s/epoch - 106ms/step
# Epoch 172/180
# 49/49 - 5s - loss: 0.0014 - accuracy: 0.9993 - val_loss: 1.2763 - val_accuracy: 0.8710 - 5s/epoch - 104ms/step
# Epoch 173/180
# 49/49 - 5s - loss: 0.0027 - accuracy: 0.9993 - val_loss: 1.2108 - val_accuracy: 0.8717 - 5s/epoch - 109ms/step
# Epoch 174/180
# 49/49 - 5s - loss: 0.0023 - accuracy: 0.9993 - val_loss: 1.0216 - val_accuracy: 0.8722 - 5s/epoch - 99ms/step
# Epoch 175/180
# 49/49 - 5s - loss: 4.3592e-04 - accuracy: 0.9999 - val_loss: 1.1074 - val_accuracy: 0.8722 - 5s/epoch - 96ms/step
# Epoch 176/180
# 49/49 - 5s - loss: 5.4135e-04 - accuracy: 0.9998 - val_loss: 1.1759 - val_accuracy: 0.8718 - 5s/epoch - 107ms/step
# Epoch 177/180
# 49/49 - 4s - loss: 7.7278e-04 - accuracy: 0.9997 - val_loss: 1.2421 - val_accuracy: 0.8715 - 4s/epoch - 84ms/step
# Epoch 178/180
# 49/49 - 5s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 1.1971 - val_accuracy: 0.8702 - 5s/epoch - 97ms/step
# Epoch 179/180
# 49/49 - 6s - loss: 7.1317e-04 - accuracy: 0.9998 - val_loss: 1.2744 - val_accuracy: 0.8695 - 6s/epoch - 114ms/step
# Epoch 180/180
# 49/49 - 4s - loss: 6.4555e-04 - accuracy: 0.9997 - val_loss: 1.1729 - val_accuracy: 0.8732 - 4s/epoch - 89ms/step
# Epoch 1/180
# 49/49 - 9s - loss: 0.4675 - accuracy: 0.7851 - val_loss: 0.2828 - val_accuracy: 0.8861 - 9s/epoch - 192ms/step
# Epoch 2/180
# 49/49 - 5s - loss: 0.2626 - accuracy: 0.8946 - val_loss: 0.2859 - val_accuracy: 0.8850 - 5s/epoch - 95ms/step
# Epoch 3/180
# 49/49 - 6s - loss: 0.1837 - accuracy: 0.9291 - val_loss: 0.2935 - val_accuracy: 0.8891 - 6s/epoch - 131ms/step
# Epoch 4/180
# 49/49 - 6s - loss: 0.1280 - accuracy: 0.9522 - val_loss: 0.3698 - val_accuracy: 0.8716 - 6s/epoch - 125ms/step
# Epoch 5/180
# 49/49 - 6s - loss: 0.0829 - accuracy: 0.9720 - val_loss: 0.4409 - val_accuracy: 0.8765 - 6s/epoch - 115ms/step
# Epoch 6/180
# 49/49 - 6s - loss: 0.0538 - accuracy: 0.9830 - val_loss: 0.5092 - val_accuracy: 0.8812 - 6s/epoch - 122ms/step
# Epoch 7/180
# 49/49 - 6s - loss: 0.0676 - accuracy: 0.9852 - val_loss: 0.5757 - val_accuracy: 0.8788 - 6s/epoch - 123ms/step
# Epoch 8/180
# 49/49 - 6s - loss: 0.0548 - accuracy: 0.9886 - val_loss: 0.5514 - val_accuracy: 0.8808 - 6s/epoch - 127ms/step
# Epoch 9/180
# 49/49 - 6s - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.9117 - val_accuracy: 0.8658 - 6s/epoch - 124ms/step
# Epoch 10/180
# 49/49 - 6s - loss: 0.0601 - accuracy: 0.9908 - val_loss: 0.7406 - val_accuracy: 0.8792 - 6s/epoch - 117ms/step
# Epoch 11/180
# 49/49 - 5s - loss: 0.0416 - accuracy: 0.9923 - val_loss: 0.7182 - val_accuracy: 0.8767 - 5s/epoch - 107ms/step
# Epoch 12/180
# 49/49 - 6s - loss: 0.0059 - accuracy: 0.9991 - val_loss: 1.1020 - val_accuracy: 0.8577 - 6s/epoch - 117ms/step
# Epoch 13/180
# 49/49 - 6s - loss: 0.0342 - accuracy: 0.9947 - val_loss: 0.8543 - val_accuracy: 0.8777 - 6s/epoch - 115ms/step
# Epoch 14/180
# 49/49 - 5s - loss: 0.0019 - accuracy: 0.9998 - val_loss: 1.0584 - val_accuracy: 0.8774 - 5s/epoch - 107ms/step
# Epoch 15/180
# 49/49 - 6s - loss: 0.0359 - accuracy: 0.9948 - val_loss: 1.0055 - val_accuracy: 0.8767 - 6s/epoch - 115ms/step
# Epoch 16/180
# 49/49 - 6s - loss: 0.0046 - accuracy: 0.9994 - val_loss: 1.0816 - val_accuracy: 0.8770 - 6s/epoch - 129ms/step
# Epoch 17/180
# 49/49 - 7s - loss: 0.0339 - accuracy: 0.9954 - val_loss: 1.0080 - val_accuracy: 0.8762 - 7s/epoch - 151ms/step
# Epoch 18/180

# %%
# Evaluate the several models on the test set
test_loss, test_accuracy = adam_lr_model.evaluate(x_test_bow, y_test, verbose=2)
print(f"Adam test accuracy: {test_accuracy:.4f}")

test_loss, test_accuracy = rmsprop_lr_model.evaluate(x_test_bow, y_test, verbose=2)
print(f"RMSprop test accuracy: {test_accuracy:.4f}")

test_loss, test_accuracy = adagrad_lr_model.evaluate(x_test_bow, y_test, verbose=2)
print(f"Adagrad test accuracy: {test_accuracy:.4f}")

test_loss, test_accuracy = sgd_lr_model.evaluate(x_test_bow, y_test, verbose=2)
print(f"SGD test accuracy: {test_accuracy:.4f}")
# Out:
# 782/782 - 3s - loss: 1.1321 - accuracy: 0.8703
# Adam test accuracy: 0.8703
# 782/782 - 3s - loss: 8.4560 - accuracy: 0.8023
# RMSprop test accuracy: 0.8023
# 782/782 - 4s - loss: 0.4927 - accuracy: 0.8782
# Adagrad test accuracy: 0.8782
# 782/782 - 4s - loss: 0.3199 - accuracy: 0.8786
# SGD test accuracy: 0.8786
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import matplotlib.pyplot as plt

# Function to plot training and validation loss
def plot_loss(histories, optimizer_names, metric='loss'):
    
    if metric == 'val_loss':
        title = 'Validation Loss'
    elif metric == 'accuracy':
        title = 'Training Accuracy'
    else:
        title = 'Training Loss'
        
    plt.figure(figsize=(14, 7))
    
    for history, name in zip(histories, optimizer_names):
        plt.plot(history.history[metric], label=f'{name} - {title}')
    
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# Plot the results

plot_loss([adam_lr_history, rmsprop_lr_history, adagrad_lr_history, sgd_lr_history], ['Adam', 'RMSprop', 'Adagrad', 'SGD'], 'loss')
plot_loss([adam_lr_history, rmsprop_lr_history, adagrad_lr_history, sgd_lr_history], ['Adam', 'RMSprop', 'Adagrad', 'SGD'], 'val_loss')
plot_loss([adam_lr_history, rmsprop_lr_history, adagrad_lr_history, sgd_lr_history], ['Adam', 'RMSprop', 'Adagrad', 'SGD'], 'accuracy')
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
